# %% [markdown]
# # Изучение рынка заведений общественного питания Москвы
#
# - Автор: Хасанов И.А.
# - Дата: 11.02.2025 (дата начала)

# %% [markdown]
# ### Цели и задачи проекта
#
# <font color='black'>Цель проекта:
# Целью данного проекта является проведение исследовательского анализа рынка общественного питания в Москве с целью предоставления инвесторам из фонда Shut Up and Take My Money обоснованных рекомендаций по выбору формата заведения (кафе, ресторан или бар), его расположения, меню и ценовой политики.
#
# Задачи проекта:
# 1. Сбор и обработка данных.
#
# 2. Анализ рынка.
#
# 3. Определить основных конкурентов в выбранных районах и форматах, проанализировав их меню, ценовую политику и уникальные предложения.
#
# 4. Определение целевой аудитории.
#
# 5. На основе проведенного анализа предложить оптимальный формат заведения (кафе, ресторан или бар) и его расположение в Москве.
#
# 6. Составить итоговый отчет с результатами анализа, выводами и рекомендациями для инвесторов.</font>

# %% [markdown]
# ### Описание данных
#
# <font color='black'>Файл /datasets/rest_info.csv содержит информацию о заведениях общественного питания:
#
# name — название заведения;
#
# address — адрес заведения;
#
# district — административный район, в котором находится заведение, например Центральный административный округ;
#
# category — категория заведения, например «кафе», «пиццерия» или «кофейня»;
#
# hours — информация о днях и часах работы;
#
# rating — рейтинг заведения по оценкам пользователей в Яндекс Картах (высшая оценка — 5.0);
#
# chain — число, выраженное 0 или 1, которое показывает, является ли заведение сетевым (для маленьких сетей могут встречаться ошибки):
#
# 0 — заведение не является сетевым;
#
# 1 — заведение является сетевым.
#
# seats — количество посадочных мест.
#
# Файл /datasets/rest_price.csv содержит информацию о среднем чеке в заведениях общественного питания:
#
# price — категория цен в заведении, например «средние», «ниже среднего», «выше среднего» и так далее;
#
# avg_bill — строка, которая хранит среднюю стоимость заказа в виде диапазона, например:
#
# «Средний счёт: 1000–1500 ₽»;
#
# «Цена чашки капучино: 130–220 ₽»;
#
# «Цена бокала пива: 400–600 ₽».
#
#
# middle_avg_bill — число с оценкой среднего чека, которое указано только для значений из столбца avg_bill, начинающихся с подстроки «Средний счёт»:
# Если в строке указан ценовой диапазон из двух значений, в столбец войдёт медиана этих двух значений.
# Если в строке указано одно число — цена без диапазона, то в столбец войдёт это число.
# Если значения нет или оно не начинается с подстроки «Средний счёт», то в столбец ничего не войдёт.
#
#
# middle_coffee_cup — число с оценкой одной чашки капучино, которое указано только для значений из столбца avg_bill, начинающихся с подстроки «Цена одной чашки капучино»:
# Если в строке указан ценовой диапазон из двух значений, в столбец войдёт медиана этих двух значений.
# Если в строке указано одно число — цена без диапазона, то в столбец войдёт это число.
# Если значения нет или оно не начинается с подстроки «Цена одной чашки капучино», то в столбец ничего не войдёт.</font>

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Привет!-👋" data-toc-modified-id="Привет!-👋-0.0.1"><span class="toc-item-num">0.0.1&nbsp;&nbsp;</span><strong>Привет!</strong> 👋</a></span></li><li><span><a href="#Ильмир:-💬-Комментарий-или-вопрос-в-такой-ячейке-я-точнно-увижу." data-toc-modified-id="Ильмир:-💬-Комментарий-или-вопрос-в-такой-ячейке-я-точнно-увижу.-0.0.2"><span class="toc-item-num">0.0.2&nbsp;&nbsp;</span><strong>Ильмир:</strong> 💬 Комментарий или вопрос в такой ячейке я точнно увижу.</a></span></li></ul></li><li><span><a href="#Цели-и-задачи-проекта" data-toc-modified-id="Цели-и-задачи-проекта-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span>Цели и задачи проекта</a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-0.2"><span class="toc-item-num">0.2&nbsp;&nbsp;</span>Описание данных</a></span></li></ul></li><li><span><a href="#1.-Загрузка-данных-и-знакомство-с-ними" data-toc-modified-id="1.-Загрузка-данных-и-знакомство-с-ними-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>1. Загрузка данных и знакомство с ними</a></span><ul class="toc-item"><li><span><a href="#Промежуточный-вывод" data-toc-modified-id="Промежуточный-вывод-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Промежуточный вывод</a></span></li><li><span><a href="#Подготовка-единого-датафрейма" data-toc-modified-id="Подготовка-единого-датафрейма-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Подготовка единого датафрейма</a></span></li></ul></li><li><span><a href="#2.-Предобработка-данных" data-toc-modified-id="2.-Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>2. Предобработка данных</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Спасибо!-Добавил-условие-&quot;круглосуточно&quot;" data-toc-modified-id="Спасибо!-Добавил-условие-&quot;круглосуточно&quot;-2.0.1"><span class="toc-item-num">2.0.1&nbsp;&nbsp;</span>Спасибо! Добавил условие "круглосуточно"</a></span></li></ul></li><li><span><a href="#Промежуточный-вывод" data-toc-modified-id="Промежуточный-вывод-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Промежуточный вывод</a></span></li></ul></li><li><span><a href="#3.-Исследовательский-анализ-данных" data-toc-modified-id="3.-Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>3. Исследовательский анализ данных</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Исправился!-Спасибо-за-замечание.-Добавил-графики-и-вывод-в-конце.-Постарался-дать-более-развернутые-рекомендации-по-имеющимся-данным." data-toc-modified-id="Исправился!-Спасибо-за-замечание.-Добавил-графики-и-вывод-в-конце.-Постарался-дать-более-развернутые-рекомендации-по-имеющимся-данным.-3.0.1"><span class="toc-item-num">3.0.1&nbsp;&nbsp;</span>Исправился! Спасибо за замечание. Добавил графики и вывод в конце. Постарался дать более развернутые рекомендации по имеющимся данным.</a></span></li></ul></li><li><span><a href="#Задача-1" data-toc-modified-id="Задача-1-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Задача 1</a></span></li><li><span><a href="#Задача-2" data-toc-modified-id="Задача-2-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Задача 2</a></span></li><li><span><a href="#Задача-3" data-toc-modified-id="Задача-3-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Задача 3</a></span></li><li><span><a href="#Задача-4" data-toc-modified-id="Задача-4-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Задача 4</a></span></li><li><span><a href="#Задача-5" data-toc-modified-id="Задача-5-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Задача 5</a></span></li><li><span><a href="#Задача-6" data-toc-modified-id="Задача-6-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Задача 6</a></span><ul class="toc-item"><li><span><a href="#Спасибо-за-совет!-Учту-в-дальнейшем." data-toc-modified-id="Спасибо-за-совет!-Учту-в-дальнейшем.-3.6.1"><span class="toc-item-num">3.6.1&nbsp;&nbsp;</span>Спасибо за совет! Учту в дальнейшем.</a></span></li><li><span><a href="#Артём:-🚨-Формально-это-неверно,-так-как-фактически-удалена-вся-часть-предобработки.-Однако-в-данном-случае-она-почти-не-требовалась,-поэтому-принято.--Но-в-будущих-проектах-это-будет-красный-комментарий." data-toc-modified-id="Артём:-🚨-Формально-это-неверно,-так-как-фактически-удалена-вся-часть-предобработки.-Однако-в-данном-случае-она-почти-не-требовалась,-поэтому-принято.--Но-в-будущих-проектах-это-будет-красный-комментарий.-3.6.2"><span class="toc-item-num">3.6.2&nbsp;&nbsp;</span><strong>Артём:</strong> 🚨 Формально это неверно, так как фактически удалена вся часть предобработки. Однако в данном случае она почти не требовалась, поэтому принято.  Но в будущих проектах это будет красный комментарий.</a></span></li><li><span><a href="#Артём:-🚨-Подсвечу-на-будущее:" data-toc-modified-id="Артём:-🚨-Подсвечу-на-будущее:-3.6.3"><span class="toc-item-num">3.6.3&nbsp;&nbsp;</span><strong>Артём:</strong> 🚨 Подсвечу на будущее:</a></span></li></ul></li><li><span><a href="#Задача-7" data-toc-modified-id="Задача-7-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Задача 7</a></span></li><li><span><a href="#Задача-8" data-toc-modified-id="Задача-8-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Задача 8</a></span></li><li><span><a href="#Задача-9" data-toc-modified-id="Задача-9-3.9"><span class="toc-item-num">3.9&nbsp;&nbsp;</span>Задача 9</a></span></li><li><span><a href="#Промежуточный-вывод" data-toc-modified-id="Промежуточный-вывод-3.10"><span class="toc-item-num">3.10&nbsp;&nbsp;</span>Промежуточный вывод</a></span></li></ul></li><li><span><a href="#4.-Итоговый-вывод-и-рекомендации" data-toc-modified-id="4.-Итоговый-вывод-и-рекомендации-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>4. Итоговый вывод и рекомендации</a></span></li><li><span><a href="#🏁-Итоги-ревью" data-toc-modified-id="🏁-Итоги-ревью-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>🏁 Итоги ревью</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Добавил-графики-и-вывод-в-конце.-Постарался-дать-более-развернутые-рекомендации-по-имеющимся-данным." data-toc-modified-id="Добавил-графики-и-вывод-в-конце.-Постарался-дать-более-развернутые-рекомендации-по-имеющимся-данным.-5.0.1"><span class="toc-item-num">5.0.1&nbsp;&nbsp;</span>Добавил графики и вывод в конце. Постарался дать более развернутые рекомендации по имеющимся данным.</a></span></li><li><span><a href="#Артём:-✌️---Ильмир,-еще-раз-спасибо-за-работу,-твои-комментарии-и-внесенные-корректировки!-Критических-замечаний-нет." data-toc-modified-id="Артём:-✌️---Ильмир,-еще-раз-спасибо-за-работу,-твои-комментарии-и-внесенные-корректировки!-Критических-замечаний-нет.-5.0.2"><span class="toc-item-num">5.0.2&nbsp;&nbsp;</span><strong>Артём:</strong> ✌️   Ильмир, еще раз спасибо за работу, твои комментарии и внесенные корректировки! Критических замечаний нет.</a></span></li></ul></li></ul></li><li><span><a href="#📖-Полезные-ссылки" data-toc-modified-id="📖-Полезные-ссылки-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>📖 <strong>Полезные ссылки</strong></a></span></li></ul></div>

# %% [markdown]
# ## 1. Загрузка данных и знакомство с ними
#
# - Загрузите данные о заведениях общественного питания Москвы. Путь к файлам: `/datasets/rest_info.csv` и `/datasets/rest_price.csv`.

# %%
# Пустые ячейки после каждого задания — примерное пространство для работы.
# Вы можете свободно добавлять или удалять ячейки по своему усмотрению в зависимости от логики и объёма работы.

# %%
# Используйте ячейки типа Code для вашего кода

# %%
# При необходимости добавьте новые ячейки для кода или удалите пустые

# %%
# Импортируем библиотеки
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pip install phik
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Загружаем библиотеку для расчёта коэффициента корреляции phi_k
from phik import phik_matrix

# %%
pd.set_option('mode.chained_assignment', None)

# %% [markdown]
# - Познакомьтесь с данными и изучите общую информацию о них.

# %%
# Выгружаем информацию о заведениях общественного питания:
rest_info = pd.read_csv('https://code.s3.yandex.net/datasets/rest_info.csv')

# %%
# Выгружаем информацию о среднем чеке в заведениях общественного питания:
rest_price = pd.read_csv('https://code.s3.yandex.net/datasets/rest_price.csv')

# %%
# Выводим первые 5 строк
rest_info.head()
# Out:
#                                  id                  name  category  \
# 0  0c3e3439a8c64ea5bf6ecd6ca6ae19f0                WoWфли      кафе
# 1  045780ada3474c57a2112e505d74b633        Четыре комнаты  ресторан
# 2  1070b6b59144425896c65889347fcff6                 Хазри      кафе
# 3  03ac7cd772104f65b58b349dc59f03ee  Dormouse Coffee Shop   кофейня
# 4  a163aada139c4c7f87b0b1c0b466a50f             Иль Марко  пиццерия
#
#                                address                         district  \
# 0           Москва, улица Дыбенко, 7/1  Северный административный округ
# 1   Москва, улица Дыбенко, 36, корп. 1  Северный административный округ
# 2       Москва, Клязьминская улица, 15  Северный административный округ
# 3  Москва, улица Маршала Федоренко, 12  Северный административный округ
# 4      Москва, Правобережная улица, 1Б  Северный административный округ
#
#                                                hours  rating  chain  seats
# ...

# %%
# Основная информация о данных в таблице
rest_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8406 entries, 0 to 8405
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        8406 non-null   object
#  1   name      8406 non-null   object
#  2   category  8406 non-null   object
#  3   address   8406 non-null   object
#  4   district  8406 non-null   object
#  5   hours     7870 non-null   object
#  6   rating    8406 non-null   float64
#  7   chain     8406 non-null   int64
#  8   seats     4795 non-null   float64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 591.2+ KB

# %% [markdown]
# ### Промежуточный вывод
# *Вывод по таблице rest_info*
#
# 1. Объём оперативной памяти, который занимает датафрейм - 591.2+ KB
# 2. Всего 8406 строк, а диапазон индексов от 0 до 8405
# 3. Всего в данных 9 столбцов
# 4. 2 стобца с типом данных float64, 6 столбцов с типом данных object(7) и 1 с типом данных int64
# 5. В данных встречаются пропуски и больше всего в столбце seats
# 6. Названия столбцов уже приведены к snake_case
#
# Необходимые изменения в таблице:
# 1. Столбец chain испльзует значения 0 и 1. Неободимо оптимизировать тип данных.
# 2. У столбца rating необходимо оптимизировать разрядность
# 3. Изучить и исключить пропуски в столбцах seats и hours
# 4. Столбец seats привести к целочисленному типу. Количество посадочных мест не может быть с типом float.

# %%
# Выводим первые 5 строк
rest_price.head()
# Out:
#                                  id          price  \
# 0  045780ada3474c57a2112e505d74b633  выше среднего
# 1  1070b6b59144425896c65889347fcff6        средние
# 2  03ac7cd772104f65b58b349dc59f03ee            NaN
# 3  a163aada139c4c7f87b0b1c0b466a50f        средние
# 4  8a343546b24e4a499ad96eb7d0797a8a        средние
#
#                         avg_bill  middle_avg_bill  middle_coffee_cup
# 0       Средний счёт:1500–1600 ₽           1550.0                NaN
# 1         Средний счёт:от 1000 ₽           1000.0                NaN
# 2  Цена чашки капучино:155–185 ₽              NaN              170.0
# 3         Средний счёт:400–600 ₽            500.0                NaN
# 4                            NaN              NaN                NaN

# %%
# Основная информация о данных в таблице
rest_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4058 entries, 0 to 4057
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 4058 non-null   object
#  1   price              3315 non-null   object
#  2   avg_bill           3816 non-null   object
#  3   middle_avg_bill    3149 non-null   float64
#  4   middle_coffee_cup  535 non-null    float64
# dtypes: float64(2), object(3)
# memory usage: 158.6+ KB

# %% [markdown]
# Вывод по таблице rest_info
#
# 1. Объём оперативной памяти, который занимает датафрейм - 158.6+ KB
# 2. Всего 4058 строк, а диапазон индексов от 0 до 4057
# 3. Всего в данных 5 столбцов
# 4. 2 стобца с типом данных float64 и 3 столбца с типом данных object(7)
# 5. В данных встречаются пропуски и больше всего в столбце middle_coffee_cup
# 6. Названия столбцов уже приведены к snake_case
#
# Необходимые изменения в таблице:
#
# 1. Изучить и исключить пропуски в столбцах middle_coffee_cup, middle_avg_bill, avg_bill и price

# %% [markdown]
# ### Подготовка единого датафрейма
#
# - Объедините данные двух датасетов в один, с которым вы и продолжите работу.

# %%
#Объединение таблиц по id
df = rest_info.merge(rest_price, on = 'id', how = 'left')

# %%
df.head()
# Out:
#                                  id                  name  category  \
# 0  0c3e3439a8c64ea5bf6ecd6ca6ae19f0                WoWфли      кафе
# 1  045780ada3474c57a2112e505d74b633        Четыре комнаты  ресторан
# 2  1070b6b59144425896c65889347fcff6                 Хазри      кафе
# 3  03ac7cd772104f65b58b349dc59f03ee  Dormouse Coffee Shop   кофейня
# 4  a163aada139c4c7f87b0b1c0b466a50f             Иль Марко  пиццерия
#
#                                address                         district  \
# 0           Москва, улица Дыбенко, 7/1  Северный административный округ
# 1   Москва, улица Дыбенко, 36, корп. 1  Северный административный округ
# 2       Москва, Клязьминская улица, 15  Северный административный округ
# 3  Москва, улица Маршала Федоренко, 12  Северный административный округ
# 4      Москва, Правобережная улица, 1Б  Северный административный округ
#
#                                                hours  rating  chain  seats  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8406 entries, 0 to 8405
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 8406 non-null   object
#  1   name               8406 non-null   object
#  2   category           8406 non-null   object
#  3   address            8406 non-null   object
#  4   district           8406 non-null   object
#  5   hours              7870 non-null   object
#  6   rating             8406 non-null   float64
#  7   chain              8406 non-null   int64
#  8   seats              4795 non-null   float64
#  9   price              3315 non-null   object
#  10  avg_bill           3816 non-null   object
#  11  middle_avg_bill    3149 non-null   float64
#  12  middle_coffee_cup  535 non-null    float64
# dtypes: float64(4), int64(1), object(8)
# memory usage: 853.9+ KB

# %% [markdown]
# Для более точного анализа данных необходимо оставить наиболее полные данные. Таким образом, тип присоединения выбран inner.
#
# Итоговое количество строк составило 8406. Далее необходимо провести преобразование типов и заполнение пропусков.
#
# Причины пропусков в данных:
# 1. Количестве посадочных мест (seats) могут быть неизвестно на момент сбора данных. Например, если заведение только планируется к открытию, и информация о количестве мест еще не определена. Если заведение изменяет свою бизнес-модель (например, переходит на другую концепцию), количество посадочных мест может стать неактуальным или неизвестным. Ошибки в программном обеспечении или в процессе обработки данных могут привести к потере информации.
#
# 2. В некоторых случаях категория цен (price), средняя стоимость заказа (avg_bill) и middle_coffee_cup может быть неизвестна на момент сбора данных. Например, если заведение только планируется к открытию, и информация о ценах еще не определена. В некоторых случаях заведение может не публиковать информацию о ценах или категориях цен, что может привести к отсутствию данных в базе.
#
# 3. Информация о днях и часах работы (hours) может отсутствовать если заведение временно закрыто или приостановило свою деятельность, информация о часах работы может быть недоступна.

# %% [markdown]
# ## 2. Предобработка данных
#
# Подготовьте данные к исследовательскому анализу:
#
# - Изучите корректность типов данных и при необходимости проведите их преобразование.

# %%
for column in ['name', 'category', 'address', 'district', 'price', 'avg_bill', 'middle_avg_bill', 'middle_coffee_cup', 'seats']:
    print(f'Уникальные значения в столбце {column}:')
    print(df[column].sort_values().unique())
# Out:
# Уникальные значения в столбце name:
# ['#КешбэкКафе' '+39 Pizzeria Mozzarella bar' '1 Этаж' ... 'Ясно' 'Яуза'
#  'ночной Баку']
# Уникальные значения в столбце category:
# ['бар,паб' 'булочная' 'быстрое питание' 'кафе' 'кофейня' 'пиццерия'
#  'ресторан' 'столовая']
# Уникальные значения в столбце address:
# ['Москва, 1-й Автозаводский проезд, 5'
#  'Москва, 1-й Балтийский переулок, 3/25'
#  'Москва, 1-й Варшавский проезд, 1Ас9' ...
#  'Москва, шоссе Энтузиастов, 86А, корп. 3' 'Москва, шоссе Энтузиастов, с2'
#  'Москва, № 7']
# Уникальные значения в столбце district:
# ['Восточный административный округ' 'Западный административный округ'
#  'Северный административный округ'
#  'Северо-Восточный административный округ'
#  'Северо-Западный административный округ'
#  'Центральный административный округ'
#  'Юго-Восточный административный округ'
#  'Юго-Западный административный округ' 'Южный административный округ']
# Уникальные значения в столбце price:
# ...

# %% [markdown]
# Выведены все уникальные значения в столбцах. Необходимо привести строковые значения к нижнему регистру.
#
# Столбец seats привести к целочисленному типу. Количество посадочных мест не может быть дробным. Для этого нужно убрать NaN в столбцах. Лучше для пропусков использовать заглушки.

# %%
df['seats'].describe()
# Out:
# count    4795.000000
# mean      108.421689
# std       122.833396
# min         0.000000
# 25%        40.000000
# 50%        75.000000
# 75%       140.000000
# max      1288.000000
# Name: seats, dtype: float64

# %% [markdown]
# Так как столбец seats содержит значения 0, то в качестве "заглушек" лучше использовать значение -1

# %%
df['seats'] = df['seats'].fillna(-1)
df['seats'] = pd.to_numeric(df['seats'], errors='coerce', downcast = 'integer')
df['seats'].dtype
# Out:
# dtype('int16')

# %%
df['middle_coffee_cup'].describe()
# Out:
# count     535.000000
# mean      174.721495
# std        88.951103
# min        60.000000
# 25%       124.500000
# 50%       169.000000
# 75%       225.000000
# max      1568.000000
# Name: middle_coffee_cup, dtype: float64

# %%
df['middle_avg_bill'].describe()
# Out:
# count     3149.000000
# mean       958.053668
# std       1009.732845
# min          0.000000
# 25%        375.000000
# 50%        750.000000
# 75%       1250.000000
# max      35000.000000
# Name: middle_avg_bill, dtype: float64

# %% [markdown]
# Столбцы middle_coffee_cup и middle_avg_bill тоже можно привести к целочисленному типу данных. В качестве заглушек можно использовать -1

# %%
df['middle_coffee_cup'] = df['middle_coffee_cup'].fillna(-1)
df['middle_avg_bill'] = df['middle_avg_bill'].fillna(-1)
df['price'] = df['price'].fillna("Нет данных")
df['avg_bill'] = df['avg_bill'].fillna("Нет данных")
df['hours'] = df['hours'].fillna("Нет данных")

# %%
df['middle_coffee_cup'] = pd.to_numeric(df['middle_coffee_cup'], errors='coerce', downcast = 'integer')
df['middle_avg_bill'] = pd.to_numeric(df['middle_avg_bill'], errors='coerce', downcast = 'integer')
df['chain'] = pd.to_numeric(df['chain'], errors='coerce', downcast = 'integer')
df['rating'] = pd.to_numeric(df['rating'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8406 entries, 0 to 8405
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 8406 non-null   object
#  1   name               8406 non-null   object
#  2   category           8406 non-null   object
#  3   address            8406 non-null   object
#  4   district           8406 non-null   object
#  5   hours              8406 non-null   object
#  6   rating             8406 non-null   float64
#  7   chain              8406 non-null   int8
#  8   seats              8406 non-null   int16
#  9   price              8406 non-null   object
#  10  avg_bill           8406 non-null   object
#  11  middle_avg_bill    8406 non-null   int32
#  12  middle_coffee_cup  8406 non-null   int16
# dtypes: float64(1), int16(2), int32(1), int8(1), object(8)
# memory usage: 665.1+ KB

# %% [markdown]
# В итоге все пропуски были заменены на "заглушки" - 0 или "Нет данных". Столбцы были приведены к неободимому типу данных. Далее следует привести к необходимому регистру и избавиться от дубликатов.

# %% [markdown]
# - Изучите пропущенные значения в данных: посчитайте их количество в каждом столбце датафрейме, изучите данные с пропущенными значениями и предположите гипотезы их появления. Проведите обработку пропущенных значений: вы можете заменить пропуски на определённое значение, удалить строки с пропусками или оставить их как есть.

# %% [markdown]
# - Проверьте данные на явные и неявные дубликаты, например поля с названием и адресом заведения. Для оптимизации проверки нормализуйте данные в текстовых столбцах, например с названием заведения.

# %%
for column in ['name', 'address', 'district', 'avg_bill']:
    df[column] = df[column].str.lower()
    
df.head()
# Out:
#                                  id                  name  category  \
# 0  0c3e3439a8c64ea5bf6ecd6ca6ae19f0                wowфли      кафе
# 1  045780ada3474c57a2112e505d74b633        четыре комнаты  ресторан
# 2  1070b6b59144425896c65889347fcff6                 хазри      кафе
# 3  03ac7cd772104f65b58b349dc59f03ee  dormouse coffee shop   кофейня
# 4  a163aada139c4c7f87b0b1c0b466a50f             иль марко  пиццерия
#
#                                address                         district  \
# 0           москва, улица дыбенко, 7/1  северный административный округ
# 1   москва, улица дыбенко, 36, корп. 1  северный административный округ
# 2       москва, клязьминская улица, 15  северный административный округ
# 3  москва, улица маршала федоренко, 12  северный административный округ
# 4      москва, правобережная улица, 1б  северный административный округ
#
#                                                hours  rating  chain  seats  \
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.duplicated(subset = ['name', 'address'], keep = False).sum()
# Out:
# 8

# %%
df.drop_duplicates(subset = ['name', 'address'], keep = 'first')
# Out:
#                                     id                  name  category  \
# 0     0c3e3439a8c64ea5bf6ecd6ca6ae19f0                wowфли      кафе
# 1     045780ada3474c57a2112e505d74b633        четыре комнаты  ресторан
# 2     1070b6b59144425896c65889347fcff6                 хазри      кафе
# 3     03ac7cd772104f65b58b349dc59f03ee  dormouse coffee shop   кофейня
# 4     a163aada139c4c7f87b0b1c0b466a50f             иль марко  пиццерия
# ...                                ...                   ...       ...
# 8401  0342ad1a45ed41ba89dcba246a8267e5            суши мания      кафе
# 8402  ee6bb7c3650e47bd8186fca08eda1091             миславнес      кафе
# 8403  62e8c64d4c89467aba608e39ef87616b               самовар      кафе
# 8404  06a0db5ecd4842d48cd6350aa923e297          чайхана sabr      кафе
# 8405  9d56f8f7a7f74df1a925bc0fd2de8aae            kebab time      кафе
#
#                                          address  \
# 0                     москва, улица дыбенко, 7/1
# ...

# %% [markdown]
# Столбцы с типом object приведены к нижнему регистру для исключения возможных неявных дубликатов. Количество дубликатов в итоговом датасете равно 0.

# %% [markdown]
# - Для дальнейшей работы создайте столбец `is_24_7` с обозначением того, что заведение работает ежедневно и круглосуточно, то есть 24/7:
#   - логическое значение `True` — если заведение работает ежедневно и круглосуточно;
#   - логическое значение `False` — в противоположном случае.

# %%
def proverka_24_7(hours):
    if 'ежедневно' and 'круглосуточно' in hours:
        return True
    else:
        return False
    
df['is_24_7'] = df['hours'].apply(proverka_24_7)
df['is_24_7'].unique()
# Out:
# array([False,  True])

# %% [markdown]
# Создан новый столбец is_24_7 с проверкой по условию 'ежедневно' и 'круглосуточно' in hours.

# %% [markdown]
# ---
#
# ### Промежуточный вывод
#
# После предобработки данных напишите промежуточный вывод о проведённой работе. Отразите количество или долю отфильтрованных данных, если вы что-то удаляли.

# %% [markdown]
# Создан единый датафрейм с типом объединения inner для исключения всевозможных пропусков.
#
# Столбцы с типом object приведены к нижнему регистру.
#
# Столбцы также приведены к оптимальному типу данных.
#
# Пропуски заполнены заглушками -1 или значением "Нет данных". Перед проставновкой значения -1 был применен метод discribe для определения минимального значения в столбцах. Иначе могла возникнуть путаница в данных.
#
# Создан столбец столбец is_24_7 с проверкой по условию 'ежедневно' в столбце hours.
#
# Итоговый датасет не содержить дубликатов. Пропуски не были удалены.

# %% [markdown]
# ## 3. Исследовательский анализ данных
# Проведите исследовательский анализ исходных данных.
#
# При исследовании данных используйте визуализации. Проверьте, что для каждого случая подобран оптимальный тип визуализации с корректным оформлением. У графика должен быть заголовок, понятные подписи по осям, при необходимости легенда, а его размер является оптимальным для изучения.
#
# После исследования каждого пункта оставляйте небольшой комментарий с выводом или обсуждением результата. В конце шага обобщите результаты, выделив, по вашему мнению, самые важные.

# %% [markdown]
# ---
#
# ### Задача 1
#
# Какие категории заведений представлены в данных? Исследуйте количество объектов общественного питания по каждой категории. Результат сопроводите подходящей визуализацией.

# %%
df['category'].unique()
# Out:
# array(['кафе', 'ресторан', 'кофейня', 'пиццерия', 'бар,паб',
#        'быстрое питание', 'булочная', 'столовая'], dtype=object)

# %%
count_categories = df.groupby('category').size().sort_values(ascending = False).reset_index(name='количество').set_index('category')
sns.heatmap(count_categories[['количество']], annot=True, fmt = '.0f', cmap = 'coolwarm')
plt.ylabel('Категория')
plt.title('Тепловая карта по количеству заведений')
# Out:
# Text(0.5, 1.0, 'Тепловая карта по количеству заведений')

# %%
plt.figure(figsize=(7, 3))

df['category'].value_counts().plot(
               kind='bar', # Тип графика - столбчатая диаграмма
               rot=45, # Градус вращения подписи по оси Х
               legend=False, # Выключаем легенду
               title=f'Количество объектов общественного питания по каждой категории',
               color='#66B3FF',
               edgecolor = 'black'
)


# Настраиваем оформление графика
plt.xlabel('Категории')
plt.ylabel('Количество объектов')
# Добавляем сетку графика
plt.grid(axis='y')

# Выводим график
plt.show()

# %% [markdown]
# В данных представлены следующие категории данных: кафе, ресторан, кофейня, пиццерия, бар/паб, быстрое питание, булочная и столовая.
# Также проанализировано количество объектов общественного питания по каждой категории.
#
# Первое, второе и третье место занимают следующие объекты: кафе (2378 объектов), ресторан (2043 объектов) и кофейня (1413 объектов) соответсвенно. Последнее место занимает категория булочная с количеством равным 256 объектам.

# %% [markdown]
# ---
#
# ### Задача 2
#
# Какие административные районы Москвы присутствуют в данных? Исследуйте распределение количества заведений по административным районам Москвы, а также отдельно распределение заведений каждой категории в Центральном административном округе Москвы. Результат сопроводите подходящими визуализациями.

# %%
df['district'].unique()
# Out:
# array(['северный административный округ',
#        'северо-восточный административный округ',
#        'северо-западный административный округ',
#        'западный административный округ',
#        'центральный административный округ',
#        'восточный административный округ',
#        'юго-восточный административный округ',
#        'южный административный округ',
#        'юго-западный административный округ'], dtype=object)

# %%
district_counts = df.groupby('district').size().sort_values(ascending = False).reset_index(name='Количество')
district_counts
# Out:
#                                   district  Количество
# 0       центральный административный округ        2242
# 1          северный административный округ         900
# 2             южный административный округ         892
# 3  северо-восточный административный округ         891
# 4          западный административный округ         851
# 5         восточный административный округ         798
# 6     юго-восточный административный округ         714
# 7      юго-западный административный округ         709
# 8   северо-западный административный округ         409

# %%
central_date = df[df['district'] == 'центральный административный округ']

central_district_categories = pd.pivot_table(central_date,
                                            index = ['district', 'category'],
                                             
aggfunc='size')

central_srted = central_district_categories.sort_values(ascending = False)

central_srted
# Out:
# district                            category
# центральный административный округ  ресторан           670
#                                     кафе               464
#                                     кофейня            428
#                                     бар,паб            364
#                                     пиццерия           113
#                                     быстрое питание     87
#                                     столовая            66
#                                     булочная            50
# dtype: int64

# %%
central_date['category'].value_counts().plot(
               kind='bar', # Тип графика - столбчатая диаграмма
               rot=45, # Градус вращения подписи по оси Х
               legend=False, # Выключаем легенду
               title=f'Количество объектов общественного питания по каждой категории в центральном административном округе',
               color='#66B3FF',
               edgecolor = 'black'
)

# Настраиваем оформление графика
plt.xlabel('Категории')
plt.ylabel('Количество объектов')
# Добавляем сетку графика
plt.grid(axis='y')

# Выводим график
plt.show()

# %% [markdown]
# В данных присутствуют следующие административные районы Москвы: северный административный округ, северо-восточный округ, северо-западный административный округ, западный административный округ, центральный административный округ, восточный  округ, юго-восточный административный округ, 'южный административный округ и 'юго-западный административный округ.
#
# Наибольшее количество заведений Москвы находится в центральном административном округе - 2242 заведения. Стоит также отметить, что количество заведений в других административных округах гораздо меньше. Наименьшее количество заведений находится в северо-западном административном округе - 409 заведений.
#
# При отдельном анализе центрального административного округа по категориям заведний было установлено, что наиболее популярными категориями являются рестораны (670 заведений), кафе (464 заведений) и кофейни (428 заведений). Последнее место занимают булочные с количеством заведений равным 50.

# %% [markdown]
# ---
#
# ### Задача 3
#
# Изучите соотношение сетевых и несетевых заведений в целом по всем данным и в разрезе категорий заведения. Каких заведений больше — сетевых или несетевых? Какие категории заведений чаще являются сетевыми? Исследуйте данные, ответьте на вопросы и постройте необходимые визуализации.

# %%
count_chain = df['chain'].value_counts()
az = df['chain'].value_counts().plot(kind = 'pie', startangle = 90, legend = True, 
                                labels = ['Несетевое заведение', 'Сетевое заведение'],
                                autopct='%1.0f%%'
)

plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
grouped = df.groupby('category')['chain'].value_counts().unstack(fill_value = 0)
grouped_1 = grouped.sort_values(by=0, ascending=False)
grouped_1 = grouped_1[grouped_1[1] > grouped_1[0]]
grouped_1
# Out:
# chain       0    1
# category
# кофейня   693  720
# пиццерия  303  330
# булочная   99  157

# %%
grouped = df.groupby('category')['chain'].value_counts().unstack(fill_value = 0)
grouped_0 = grouped.sort_values(by=0, ascending=False)
grouped_0 = grouped_0[grouped_0[0] > grouped_0[1]]
grouped_0
# Out:
# chain               0    1
# category
# кафе             1599  779
# ресторан         1313  730
# бар,паб           596  169
# быстрое питание   371  232
# столовая          227   88

# %%
grouped = df.groupby('category')['chain'].value_counts().unstack(fill_value = 0)
grouped_sorted = grouped.sort_values(by=0, ascending=False)

ax = grouped_sorted.plot(kind='bar',
               title=f'Распределение заведений в зависимости от типа',
               legend=True,
               ylabel='Количество заведений',
               xlabel='Категория заведения',
               rot=45,
               figsize=(7, 3)          
            
)
plt.grid(axis='y')
new_labels = ['Несетевое заведение', 'Сетевое заведение']
ax.legend(new_labels, title='Тип заведения')

# Выводим график
plt.show()

# %% [markdown]
# Установлено, что по всем данным несетевых заведений гораздо больше сетевых. Несетевых заведений 62 %, тогда как сетевых всего 38 %.
#
# Чаще всего являются сетевыми следующие категории заведений: кофейня (720 заведений), пиццерия (330 заведений) и булочная (157 заведений).
#
# Самыми популярными несетевыми заведениями являются: кафе (1599 заведений), ресторан (1313 заведений) и бар/паб (596 заведений).

# %% [markdown]
# ---
#
# ### Задача 4
#
# Исследуйте количество посадочных мест в заведениях. Встречаются ли в данных аномальные значения или выбросы? Если да, то с чем они могут быть связаны? Приведите для каждой категории заведений наиболее типичное для него количество посадочных мест. Результат сопроводите подходящими визуализациями.

# %%
df_clear_seats = df.loc[(df['seats'] != -1)]
df_clear_seats['seats'].describe()
# Out:
# count    4795.000000
# mean      108.421689
# std       122.833396
# min         0.000000
# 25%        40.000000
# 50%        75.000000
# 75%       140.000000
# max      1288.000000
# Name: seats, dtype: float64

# %%
boxplot = df_clear_seats.boxplot(column = 'seats',
                    vert = False,
                    figsize=(9, 4),
                    color='#66B3FF')

boxplot.set_title('Распределения количества посадочных мест')
boxplot.set_xlabel('Количество посадочных мест')
# Out:
# Text(0.5, 0, 'Количество посадочных мест')

# %%
ax = df_clear_seats['seats'].hist(figsize = (9, 4),
              color='#66B3FF',
              edgecolor = 'black')

ax.set_title('Распределения количества посадочных мест')
ax.set_ylabel('количество(частота)')
ax.set_xlabel('Количество посадочных мест')


plt.grid(axis='y')

# %%
mean_seats_count = df_clear_seats.groupby('category')['seats'].mean().sort_values()

order_sorted = mean_seats_count.index

ay = sns.boxplot(x = 'seats', y = 'category', data = df_clear_seats, order=order_sorted)

az.set_title('Распределения количества посадочных мест с выбросами')
az.set_ylabel('Категории заведений')
az.set_xlabel('Количество посадочных мест')
# Out:
# Text(0.5, 4.4444444444444375, 'Количество посадочных мест')

# %%
mean_seats_count = df_clear_seats.groupby('category')['seats'].mean().sort_values()

order_sorted = mean_seats_count.index

ay = sns.boxplot(x = 'seats', y = 'category', data = df_clear_seats, showfliers=False, order=order_sorted)

ay.set_title('Распределения количества посадочных мест без выбросов')
ay.set_ylabel('Категории заведений')
ay.set_xlabel('Количество посадочных мест')
# Out:
# Text(0.5, 0, 'Количество посадочных мест')

# %%
titpical_seats = round(df_clear_seats.groupby('category')['seats'].median().sort_values(ascending
 = False), 0)
titpical_seats
# Out:
# category
# ресторан           86.0
# бар,паб            82.0
# кофейня            80.0
# столовая           76.0
# быстрое питание    65.0
# кафе               60.0
# пиццерия           55.0
# булочная           50.0
# Name: seats, dtype: float64

# %%
az = df_clear_seats.groupby('category')['seats'].median().sort_values(ascending
 = False).plot(kind='bar',
              color='#66B3FF',
              edgecolor = 'black')

az.set_title('Наиболее типичное количество посадочных мест (ср.знач)')
az.set_xlabel('Категория')
az.set_ylabel('Среднее количество посадочных мест')


plt.grid(axis='y')

# %% [markdown]
# Проведена оценка разброса данных по количеству посадочных мест. Установлено, что в данных по количеству мест можно наблюдать существенный разброс, так как стандартное отклонение выше среднего значения. Правый хвост распределения длиннее левого. Таким образом, мы наблюдаем правоасимметричное распределение.
#
# Для визуализации выбросов по посадочным местам построена гистограмма и "ящик с усами". Установлено, что в данных наблюдается большое количество выбросов. Также построен график "ящик с усами" с группировкой по категориям заведений. Аналогичная картина с наличием выбросов наблюдается во всех категориях. Аномальные значения доходят до 1288 мест, что может быть ошибкой в данных.
#
# Для расчета наиболее типичного количества посадочных мест была выбрана медиана, так как в данных имеется большое количество выбросов.
# Наиболее типичное количество мест для каждой категории заведений: ресторан - 86 мест, бар,паб - 82 мест, кофейня - 80 мест, столовая - 76 мест, быстрое питание - 65 мест, кафе - 60 мест, пиццерия - 55 мест и булочная - 50 мест.

# %% [markdown]
# ---
#
# ### Задача 5
#
# Исследуйте рейтинг заведений. Визуализируйте распределение средних рейтингов по категориям заведений. Сильно ли различаются усреднённые рейтинги для разных типов общепита?

# %%
df['rating'].describe()
# Out:
# count    8406.000000
# mean        4.229895
# std         0.470348
# min         1.000000
# 25%         4.100000
# 50%         4.300000
# 75%         4.400000
# max         5.000000
# Name: rating, dtype: float64

# %%
az = df.groupby('category')['rating'].mean().sort_values(ascending = False).plot(kind='bar')

az.set_title('распределение средних рейтингов по категориям заведений')
az.set_xlabel('Категория')
az.set_ylabel('Средний рейтинг')

plt.grid(axis='y')

# %%
rating_category = df.groupby('category')['rating'].mean().sort_values(ascending = False)
rating_category
# Out:
# category
# бар,паб            4.387712
# пиццерия           4.301264
# ресторан           4.290357
# кофейня            4.277282
# булочная           4.268359
# столовая           4.211429
# кафе               4.123886
# быстрое питание    4.050249
# Name: rating, dtype: float64

# %% [markdown]
# Усреднённые рейтинги для разных типов общепита различаются не так сильно. Это можно наблюдать на визуализации. Также стандартное отклонение составляет всего 0,47.
#
# Наиболее высокооцениваемой категорией является бар/паб со средней оценкой равной 4,39. Худшей категорией являются рестораны быстрого питания со средней оценкой равной 4,05.

# %% [markdown]
# ---
#
# ### Задача 6
#
# Изучите, с какими данными показывают самую сильную корреляцию рейтинги заведений? Постройте и визуализируйте матрицу корреляции рейтинга заведения с разными данными: его категория, положение (административный район Москвы), статус сетевого заведения, количество мест, ценовая категория и признак, является ли заведения круглосуточным. Выберите самую сильную связь и проверьте её.

# %%
#Создаем копию датафрейма и заменяем заглушки на пропуски для изучения корреляции рейтинга заведения с разными данными
df_with_NaN = df.copy()
df_with_NaN.replace([-1, 'Нет данных'], np.nan, inplace = True)

# %%
# переводим необходимые столбцы в датафрейме df_with_NaN на 'category'
df_with_NaN['category'] = df_clear_seats['category'].astype('category')
df_with_NaN['district'] = df_clear_seats['district'].astype('category')
df_with_NaN['price'] = df_clear_seats['price'].astype('category')
df_with_NaN.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8406 entries, 0 to 8405
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 8406 non-null   object
#  1   name               8406 non-null   object
#  2   category           4795 non-null   category
#  3   address            8406 non-null   object
#  4   district           4795 non-null   category
#  5   hours              7870 non-null   object
#  6   rating             8406 non-null   float64
#  7   chain              8406 non-null   int8
#  8   seats              4795 non-null   float64
#  9   price              4795 non-null   category
#  10  avg_bill           8406 non-null   object
#  11  middle_avg_bill    3149 non-null   float64
#  12  middle_coffee_cup  535 non-null    float64
#  13  is_24_7            8406 non-null   bool
# dtypes: bool(1), category(3), float64(4), int8(1), object(5)
# memory usage: 633.1+ KB

# %%
len(df_with_NaN)
# Out:
# 8406

# %%
df_correlation = df_with_NaN.loc[(df_with_NaN['is_24_7'] != 'False')]

correlation_matrix = df_correlation[['category', 'district', 'rating',
       'chain', 'seats', 'price', 'is_24_7']].phik_matrix()

sns.heatmap(correlation_matrix[['rating']].sort_values(by = 'rating', ascending = False), annot = True, fmt = '.2f', cmap = 'coolwarm')
# Out:
# interval columns not set, guessing: ['rating', 'chain', 'seats']
# <Axes: >

# %%
ar = df_with_NaN.groupby('price')['rating'].mean().sort_values().plot(kind = 'line')

ar.set_title('Анализ категорий цен от рейтинга')

ar.set_xlabel('Категория цен')

ar.set_ylabel('Рейтинг')
# Out:
# C:\Users\Ilmir\AppData\Local\Temp\ipykernel_13420\3448136300.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   ar = df_with_NaN.groupby('price')['rating'].mean().sort_values().plot(kind = 'line')
# Text(0, 0.5, 'Рейтинг')

# %%
df_correlation_analize = df_with_NaN.groupby('price')['rating'].mean().sort_values()
df_correlation_analize
# Out:
# C:\Users\Ilmir\AppData\Local\Temp\ipykernel_13420\3713270216.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_correlation_analize = df_with_NaN.groupby('price')['rating'].mean().sort_values()
# price
# Нет данных       4.176721
# низкие           4.195876
# средние          4.296003
# выше среднего    4.383473
# высокие          4.436562
# Name: rating, dtype: float64

# %% [markdown]
# Количество заведений сильно уменьшилось, так как из нашей базы данных были исключены все некорректные значения, которые могут повлиять на анализ.
#
# Рейтинги заведений показывают самую сильную корреляцию с категорией цен в заведении - 0,26.
#
# При проверке самой сильной связи между рейтингом и категорией цен в заведении было установлено, что чем выше категория цен в заведении, то тем выше рейтинг - 4,43. Категория цен в заведении и рейтинг имеют линейную положительную связь.
#
# Стоит также учитывать, что в столбце price есть пропуски. Это может быть связано с неоднородность категорий. Если заведение предлагает широкий спектр услуг или товаров, оно может не подходить под стандартные категории цен. Например, ресторан может предлагать как недорогие, так и дорогие блюда, что затрудняет классификацию.

# %% [markdown]
# ---
#
# ### Задача 7
#
# Сгруппируйте данные по названиям заведений и найдите топ-15 популярных сетей в Москве. Для них посчитайте значения среднего рейтинга. Под популярностью понимается количество заведений этой сети в регионе. К какой категории заведений они относятся? Результат сопроводите подходящими визуализациями.

# %%
df_chain_1 = df.loc[(df['chain'] == 1)]

name_counts = df_chain_1.groupby(['name', 'category']).agg(количество = ('name', 'size'), рейтинг = ('rating', 'mean'))

name_counts_sort = name_counts.sort_values(by = 'количество', ascending = False).head(15)
name_counts_sort
# Out:
#                                               количество   рейтинг
# name                                category
# шоколадница                         кофейня          119  4.178151
# домино'с пицца                      пиццерия          76  4.169737
# додо пицца                          пиццерия          74  4.286486
# one price coffee                    кофейня           71  4.064789
# яндекс лавка                        ресторан          69  3.872464
# cofix                               кофейня           65  4.075385
# prime                               ресторан          49  4.114286
# кофепорт                            кофейня           42  4.147619
# кулинарная лавка братьев караваевых кафе              39  4.394872
# теремок                             ресторан          36  4.105556
# cofefest                            кофейня           31  3.977419
# чайхана                             кафе              26  3.946154
# ...

# %%
#count_name = df.groupby('category')['name'].size().sort_values(ascending = False)

count_name = df_chain_1.groupby('name').size().sort_values(ascending = False).head(15)

fig1, ax1 = plt.subplots(figsize=(10, 7))

count_name.plot(kind = 'bar', ax=ax1, alpha=0.8)
ax1.set_ylabel('Количество заведений')

ax2 = ax1.twinx()

mean_raiting = df_chain_1[df_chain_1['name'].isin(count_name.index)].groupby('name')['rating'].mean()

mean_raiting = mean_raiting.reindex(count_name.index)

mean_raiting.plot(ax = ax2, color = 'orange')
ax2.set_ylabel('Средний рейтинг')
plt.title('Количество сетевых заведений и средний рейтинг по категориям')
ax1.set_xlabel('Название заведения')
# Out:
# Text(0.5, 0, 'Название заведения')

# %% [markdown]
# Топ 15 заведений в г.Москва и категории к которым они относятся (название - категория):
# 1. шоколадница	- кофейня
# 2. домино'с пицца	- пиццерия (76 заведений);
# 3. додо пицца - пиццерия (74 заведений);
# 4. one price coffee - кофейня (71 заведений);
# 5. яндекс лавка - ресторан (69 заведений);
# 6. cofix - кофейня (65 заведений);
# 7. prime - ресторан (49 заведений);
# 8. кофепорт - кофейня	(42 заведений);
# 9. кулинарная лавка братьев караваевых	- кафе (39 заведений);
# 10. теремок	- ресторан (36 заведений);
# 11. cofefest - кофейня	(31 заведений);
# 12. чайхана	- кафе (26 заведений);
# 13. буханка	- булочная (25 заведений);
# 14. drive café - кафе (24 заведений);
# 15. кофемания - кофейня	(22 заведений).
#
#
# У самого популярного заведения "шоколадница" средний рейтинг (4,2).

# %% [markdown]
# ---
#
# ### Задача 8
#
# Изучите вариацию среднего чека заведения (столбец `middle_avg_bill`) в зависимости от района Москвы. Проанализируйте цены в Центральном административном округе и других. Как удалённость от центра влияет на цены в заведениях? Результат сопроводите подходящими визуализациями.

# %%
df_arerage = df.loc[(df['middle_avg_bill'] != -1)]
middle_avg_bill_count = df_arerage.groupby('district')['middle_avg_bill'].mean().sort_values(ascending=False)
aw = df_arerage.groupby('district')['middle_avg_bill'].mean().sort_values(ascending=False).plot(kind = 'bar')

aw.set_title('Анализ среднего чека заведения')
aw.set_ylabel('Медианное значение среднего чека')

for index, value in enumerate(df_arerage.groupby('district')['middle_avg_bill'].mean().sort_values(ascending=False)):
    aw.text(index, value, f'{value:.0f}', ha='center', va='bottom')

# %%
# df_arerage в котором уже нет значений -1 и теперь будет только 'центральный административный округ'
df_arerage_central = df_arerage.loc[(df_arerage['district'] == 'центральный административный округ')]
df_arerage_another = df_arerage.loc[(df_arerage['district'] != 'центральный административный округ')]

df_arerage['group'] = df_arerage['district'].apply(lambda x: 'центральный административный округ' if x == 'центральный административный округ' else 'другие районы')

order = ['центральный административный округ', 'другие районы']

sns.boxplot(x = 'group', y = 'middle_avg_bill', data = df_arerage, showfliers=False, order=order)
plt.title('Распределение среднего чека: Центрального округа и Других районов')
plt.ylabel('Средний чек')
plt.xlabel("")
# Out:
# Text(0.5, 0, '')

# %% [markdown]
# Средний чек в центральном административном округе значительно выше чем в других районах Москвы. Возможно, чем дальше заведение от центра, тем меньше у него средний чек, но для проверки данной гипотезы необходимо использовать карты.
#
# Стоит отметить тройку лидеров по среднему чеку в заведениях:
# 1. Центральный административный округ - 1191
# 2. Западный административный округ - 1053
# 3. Северный административный округ - 928
#
# Самый худший показатель можно наблюдать в юго-восточном административном округе, где средний чек всего 654.

# %% [markdown]
# ---
#
# ### Задача 9
#
#  При необходимости проведите исследования других данных и их взаимосвязи. Например, часы работы заведений или стоимость чашки кофе в зависимости от расположения или типа заведения.

# %%
df_coffee_cup = df.loc[(df['middle_coffee_cup'] != -1)]

ay = df_coffee_cup.groupby('district')['middle_coffee_cup'].mean().sort_values(ascending=False).plot(kind = 'bar')

ay.set_title('Оценка по одной чашке капучино')
ay.set_xlabel('Административные районы')
ay.set_ylabel('Медианное значение')


for index, value in enumerate(df_coffee_cup.groupby('district')['middle_coffee_cup'].mean().sort_values(ascending=False)):
    ay.text(index, value, f'{value:.0f}', ha='center', va='bottom')

# %%
at = df_coffee_cup.boxplot(column='middle_coffee_cup', by='district', vert = False)

at.set_title('Оценка распределению данных по оценке стиомости одной чашки капучино')
at.set_ylabel('Административные районы')
at.set_xlabel('')
# Out:
# Text(0.5, 0, '')

# %% [markdown]
# Проведена оценка по одной чашке капучино в зависимости от района:
# 1. Западный административный округ - 190
# 2. центральный административный округ - 188
# 3. юго-западный административный округ - 183
#
# Худший показатель у юго-восточного административного округа -151
#
# Также стоит отметить наличие выбросов в данных восточного административного округа. Скорее всего это ошибка в данных.

# %% [markdown]
# ---
#
# ### Промежуточный вывод
#
# Обобщите полученные результаты, выделив, по вашему мнению, самые важные.

# %% [markdown]
# В результате анализа данных о заведениях общественного питания в Москве были выявлены несколько ключевых моментов:
#
# 1. Категории заведений: Наиболее распространённые категории — кафе (2378 объектов), рестораны (2043 объекта) и кофейни (1413 объектов). Наименьшее количество заведений представлено в категории булочных (256 объектов).
# 2. Распределение по административным округам: Центральный административный округ лидирует по количеству заведений (2242), в то время как северо-западный округ имеет наименьшее количество (409). В центральном округе наиболее популярны рестораны (670), кафе (464) и кофейни (428).
# 3. Сетевые и несетевые заведения: Преобладают несетевые заведения (62%), в то время как сетевые составляют 38%. Среди сетевых наиболее распространены кофейни (720), пиццерии (330) и булочные (157). Несетевые заведения представлены кафе (1599), ресторанами (1313) и барами/пабами (596).
# 4. Посадочные места: Данные о количестве посадочных мест имеют значительный разброс, с правым хвостом распределения. Медианное количество мест варьируется от 50 (булочные) до 86 (рестораны).
# 5. Корреляция рейтингов: Рейтинги заведений имеют положительную линейную связь с административным районом (корреляция 0,27). Наиболее популярное заведение — кафе — имеет самый низкий средний рейтинг (3,8).
# 6. Средний чек: Средний чек в центральном округе (1191) значительно выше, чем в других округах, с наименьшим значением в юго-восточном округе (654). Также наблюдается связь между ценовой категорией и рейтингом: чем выше цена, тем выше рейтинг.
# 7. Анализ цен на капучино: Цены на капучино варьируются от 190 рублей в западном округе до 151 рубля в юго-восточном округе, что также указывает на различия в ценовой политике.
# 8. Выбросы в данных: В данных наблюдаются выбросы, особенно в количестве посадочных мест и ценах, что может указывать на ошибки в данных и требует дополнительной проверки.

# %% [markdown]
# ## 4. Итоговый вывод и рекомендации
#
# По результатам проведённого исследовательского анализа данных сформулируйте итоговый вывод и рекомендации для заказчика. Старайтесь акцентировать внимание на ключевых моментах исследования.
#
# При составлении вывода придерживайтесь такой структуры:
#
# 1. Общий обзор проделанной работы.
# 2. Ответы на исследовательские вопросы, или главные выводы.
# 3. Рекомендации на основе анализа данных.

# %% [markdown]
# В работе проанализировали датасет с заведениями общественного питания Москвы, составленный на основе данных сервисов Яндекс Карты и Яндекс Бизнес на лето 2022 года. Акцент исследования был на категории, популярности и рейтинге заведений в зависимости от района Москвы.
#
# Итоговые ответы на вопросы:
# В данных представлены следующие категории заведений: кафе, ресторан, кофейня, пиццерия, бар/паб, быстрое питание, булочная и столовая. Также проанализировано количество объектов общественного питания по каждой категории.
# Определено количество объектов общественного питания по каждой категории:

# %%
count_categories
# Out:
#                  количество
# category
# кафе                   2378
# ресторан               2043
# кофейня                1413
# бар,паб                 765
# пиццерия                633
# быстрое питание         603
# столовая                315
# булочная                256

# %% [markdown]
# В данных присутствуют следующие административные районы Москвы: северный административный округ, северо-восточный округ, северо-западный административный округ, западный административный округ, центральный административный округ, восточный округ, юго-восточный административный округ, 'южный административный округ и 'юго-западный административный округ.
#
# Количество заведений по административным районам Москвы:

# %%
district_counts
# Out:
#                                   district  Количество
# 0       центральный административный округ        2242
# 1          северный административный округ         900
# 2             южный административный округ         892
# 3  северо-восточный административный округ         891
# 4          западный административный округ         851
# 5         восточный административный округ         798
# 6     юго-восточный административный округ         714
# 7      юго-западный административный округ         709
# 8   северо-западный административный округ         409

# %% [markdown]
# Распределение количества заведений в центральном административном округе:

# %%
central_srted
# Out:
# district                            category
# центральный административный округ  ресторан           670
#                                     кафе               464
#                                     кофейня            428
#                                     бар,паб            364
#                                     пиццерия           113
#                                     быстрое питание     87
#                                     столовая            66
#                                     булочная            50
# dtype: int64

# %% [markdown]
# Установлено, что по всем данным несетевых заведений гораздо больше сетевых. Несетевых заведений 62 %, тогда как сетевых всего 38 %.
# Сетевыми являются следующие категории заведений: кофейня (720 заведений), пиццерия (330 заведений) и булочная (157 заведений).
# Самыми популярными несетевыми заведениями являются: кафе (1599 заведений), ресторан (1313 заведений) и бар/паб (596 заведений).
#
# Наиболее типичное количество посадочных мест для каждой категории заведений:

# %%
titpical_seats
# Out:
# category
# ресторан           86.0
# бар,паб            82.0
# кофейня            80.0
# столовая           76.0
# быстрое питание    65.0
# кафе               60.0
# пиццерия           55.0
# булочная           50.0
# Name: seats, dtype: float64

# %% [markdown]
# Наиболее типичное количество посадочных мест для каждой категории заведений: ресторан - 86 мест, бар,паб - 82 мест, кофейня - 80 мест, столовая - 76 мест, быстрое питание - 65 мест, кафе - 60 мест, пиццерия - 55 мест и булочная - 50 мест.
# Установлено, что в данных наблюдается большое количество выбросов. Аномальные значения или выбросы в количестве посадочных мест могут быть связаны с несколькими факторами:
# 1. Неправильный ввод данных, опечатки или некорректные записи;
# 2. Изменения в правилах, касающихся размещения и количества мест, могут также влиять на данные. Например, новые нормы по безопасности могут требовать уменьшения количества мест;
# 3. Заведения могут изменять количество посадочных мест в зависимости от сезона, мероприятий или изменений в концепции;
# 4. Некоторые заведения могут иметь значительно большее количество посадочных мест, чем типично для их категории. Это может быть связано с особенностями концепции заведения, например, крупные рестораны, банкетные залы или заведения, ориентированные на массовое обслуживание.

# %% [markdown]
# Усреднённые рейтинги для разных типов общепита различаются не так сильно.

# %%
rating_category
# Out:
# category
# бар,паб            4.387712
# пиццерия           4.301264
# ресторан           4.290357
# кофейня            4.277282
# булочная           4.268359
# столовая           4.211429
# кафе               4.123886
# быстрое питание    4.050249
# Name: rating, dtype: float64

# %% [markdown]
# Также стандартное отклонение составляет всего 0,47. Наиболее высокооцениваемой категорией является бар/паб со средней оценкой равной 4,39. Худшей категорией являются рестораны быстрого питания со средней оценкой равной 4,05.

# %% [markdown]
# Рейтинги заведений показывают самую сильную корреляцию с категорией цен в заведении - 0,26.

# %%
correlation_matrix['rating'].sort_values(ascending = False)
# Out:
# rating      1.000000
# price       0.264696
# district    0.186543
# category    0.185692
# is_24_7     0.144762
# chain       0.108092
# seats       0.000000
# Name: rating, dtype: float64

# %% [markdown]
# Проверка самой сильной связи между рейтингом и категорией цен в заведении:

# %%
df_correlation_analize
# Out:
# price
# Нет данных       4.176721
# низкие           4.195876
# средние          4.296003
# выше среднего    4.383473
# высокие          4.436562
# Name: rating, dtype: float64

# %% [markdown]
# При проверке самой сильной связи между рейтингом и категорией цен в заведении было установлено, что чем выше категория цен в заведении, то тем выше рейтинг. Категория цен в заведении и рейтинг имеют линейную положительную связь.
#
# Стоит также учитывать, что в столбце price есть пропуски. Это может быть связано с неоднородность категорий. Если заведение предлагает широкий спектр услуг или товаров, оно может не подходить под стандартные категории цен. Например, ресторан может предлагать как недорогие, так и дорогие блюда, что затрудняет классификацию.

# %% [markdown]
# Топ-15 популярных сетей в Москве с обозначением среднего рейтинга и категорией:

# %%
name_counts_sort
# Out:
#                                               количество   рейтинг
# name                                category
# шоколадница                         кофейня          119  4.178151
# домино'с пицца                      пиццерия          76  4.169737
# додо пицца                          пиццерия          74  4.286486
# one price coffee                    кофейня           71  4.064789
# яндекс лавка                        ресторан          69  3.872464
# cofix                               кофейня           65  4.075385
# prime                               ресторан          49  4.114286
# кофепорт                            кофейня           42  4.147619
# кулинарная лавка братьев караваевых кафе              39  4.394872
# теремок                             ресторан          36  4.105556
# cofefest                            кофейня           31  3.977419
# чайхана                             кафе              26  3.946154
# ...

# %% [markdown]
# У самого популярного сетевого заведения "шоколадница" средний рейтинг (4,2).

# %% [markdown]
# Средний чек в центральном административном округе значительно выше чем в других районах Москвы. Возможно, чем дальше заведение от центра, тем меньше у него средний чек, но для проверки данной гипотезы необходимо использовать карты.
#
# Средний чек в заведениях:

# %%
round(middle_avg_bill_count, 1)
# Out:
# district
# центральный административный округ         1191.1
# западный административный округ            1053.2
# северный административный округ             928.0
# южный административный округ                834.4
# северо-западный административный округ      822.2
# восточный административный округ            820.6
# юго-западный административный округ         792.6
# северо-восточный административный округ     716.6
# юго-восточный административный округ        654.1
# Name: middle_avg_bill, dtype: float64

# %% [markdown]
# Стоит отметить тройку лидеров по среднему чеку в заведениях:
#
# Центральный административный округ - 1191
# Западный административный округ - 1053
# Северный административный округ - 928
# Самый худший показатель можно наблюдать в юго-восточном административном округе, где средний чек всего 654.

# %% [markdown]
# Проведен анализ категорий цен от рейтинга и установлено, что чем выше категория цен, то тем больше рейтинг у заведения.
#
# Также проведена оценка по одной чашке капучино в зависимости от района:
#
# 1. Западный административный округ - 190
# 2. центральный административный округ - 188
# 3. юго-западный административный округ - 183
# 4. Худший показатель у юго-восточного административного округа - 151

# %% [markdown]
# <p style="font-size: 30px;">Рекомендации</p>
#
# Исходя из представленных данных о количестве заведений в различных административных округах Москвы, можно сделать несколько рекомендаций по выбору более выгодных районов для размещения новых заведений общественного питания:
# 1.  Наибольшее количество заведений в центральном административном округе (2242 заведений) указывает на высокую концентрацию клиентов и активный спрос. Это может быть выгодным местом для открытия новых заведений, особенно если они предлагают уникальные концепции или высококачественные услуги. Рассмотрите возможность открытия заведений с высокой добавленной стоимостью, таких как рестораны высокой кухни, кофейни с уникальными предложениями.
# 2. Юго-западный и Северо-западный административные округа имеют наименьшее количество заведений (709 и 409 соответственно). Это может указывать на менее насыщенный рынок, но также может означать меньший спрос. Перед открытием заведения в этих округах стоит провести более глубокий анализ рынка. Возможно, стоит рассмотреть открытие уникальных концептуальных заведений, которые могут привлечь внимание и создать спрос.
#
# На основе представленных данных о количестве заведений в различных категориях можно выделить несколько рекомендаций относительно категорий, которые пользуются наибольшим спросом, а также объяснить причины этого спроса:
# 1. Открытие кафе (2378 заведений) с уникальной концепцией, например, тематические кафе или заведения с акцентом на здоровое питание, может привлечь дополнительный интерес.
# 2. Также популярностью пользуются рестораны (2043 заведения) и причиной популярности может быть широкий выбор блюд и высокое качество обслуживания, что привлекает клиентов, ищущих полноценный обед или ужин. Рассмотрите возможность открытия ресторанов с уникальными кулинарными концепциями, такими как кухни разных стран или авторская кухня.
# 3. Замыкает тройку лидеров кофейни (1413 заведений). Открытие кофейни с акцентом на уникальные сорта кофе, а также создание комфортной атмосферы для работы может привлечь постоянных клиентов. Причиной популярности может быть использование кофейни как места для работы или учебы, что увеличивает их посещаемость.
#
# Перед открытием сетевого или несетевого заведения стоит выполнить дополнительный анализ, так как на данный момент при оценке количества заведений было установлено, что по всем данным несетевых заведений гораздо больше сетевых. Несетевых заведений 62 %, тогда как сетевых всего 38 %. Однако в некоторых категориях сетевых заведений было больше (кофейня (720 заведений), пиццерия (330 заведений) и булочная (157 заведений)). Таким образом, перед открытем того или иного заведния следует:
# 1. Провести анализ рынка, чтобы понять, какие категории и концепции наиболее востребованы в конкретном районе.
# 2. Независимым заведениям стоит сосредоточиться на создании уникального предложения, которое выделит их на фоне сетевых конкурентов.
# 3. Оба типа заведений должны уделять внимание качеству обслуживания, так как это критически важно для удержания клиентов.
# 4. Независимым заведениям стоит использовать локальные маркетинговые стратегии, чтобы привлечь клиентов, поддерживающих местные бизнесы.
#
#
# На основе представленной информации о топ-15 популярных сетях в Москве с указанием среднего рейтинга и категории, можно выделить несколько рекомендаций для бизнеса в сфере общественного питания.
# Анализ успешных категорий:
# 1. Кофейни: В списке представлено множество кофейных сетей с высокими рейтингами (например, "Шоколадница", "Кофемания", "Кофепорт"). Это указывает на высокий спрос на кофейни в Москве.
# - Рекомендация: Рассмотрите возможность открытия кофейни с уникальной концепцией, например, с акцентом на специальные сорта кофе или атмосферу для работы и встреч.
# 2. Пиццерии: Сети, такие как "Додо Пицца" и "Домино'с Пицца", также имеют высокие рейтинги и популярность.
# - Рекомендация: Открытие пиццерии с акцентом на качественные ингредиенты и уникальные рецепты может привлечь клиентов. Рассмотрите возможность доставки и самовывоза.
# 3. Рестораны и кафе: Сети, такие как "Яндекс Лавка" и "Кулинарная лавка братьев Караваевых", показывают, что рестораны и кафе также могут быть успешными.
# - Рекомендация: Создание ресторана или кафе с уникальным меню и акцентом на качество обслуживания может привлечь клиентов. Учитывайте возможность организации мероприятий или специальных предложений.
#
#
# На основе предоставленных данных о среднем количестве посадочных мест для каждой категории заведений, можно дать следующие рекомендации.
# 1. Ресторан:
# - Оптимально иметь от 70 до 100 мест, чтобы обеспечить баланс между комфортом и возможностью обслуживания большего числа клиентов в часы пик. Создание отдельных залов для групповых мероприятий или частных ужинов. Рестораны, как правило, ориентированы на полноценные обеды и ужины, поэтому количество мест должно обеспечивать комфортное размещение клиентов.
# 2. Бар/Паб:
# - важно создать атмосферу, способствующую общению. Оптимальное количество мест может варьироваться от 60 до 100, в зависимости от концепции (например, наличие танцпола или живой музыки). Учитывайте возможность размещения высоких столов и барных стоек для создания более непринужденной атмосферы.
# 3. Кофейня:
# - Оптимальное количество мест — от 50 до 90, с акцентом на создание уютных уголков для работы и общения. Рассмотрите возможность создания террасы или открытого пространства для привлечения клиентов в теплое время года.
# 4. Столовая:
# - Оптимально иметь от 60 до 80 мест, с возможностью быстрой смены столов. Учитывайте возможность организации самообслуживания для ускорения процесса.
# 5. Кафе:
# - Оптимальное количество мест — от 40 до 70, с акцентом на удобство и скорость обслуживания. Рассмотрите возможность организации зоны для выноса и доставки.
# 6. Пиццерия:
# - Оптимальное количество мест — от 40 до 70, с акцентом на возможность быстрого обслуживания.
# 7. Булочная:
# - Оптимальное количество мест — от 20 до 40, с акцентом на удобство для клиентов, ожидающих свои заказы. Булочные обычно ориентированы на продажу выпечки и десертов, поэтому количество мест может быть ограниченным. Учитывайте возможность организации зоны для кофе и выпечки, чтобы привлечь клиентов.
